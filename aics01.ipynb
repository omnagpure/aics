# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix

# Load dataset
df = pd.read_csv("emails.csv")

# Input and output
X = df["Message"]
y = df["Category"]

# Convert text to numbers
cv = CountVectorizer()
X = cv.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = MultinomialNB()
model.fit(X_train, y_train)

# Predict test data
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Test new message
new_msg = ["Hey there! Just wanted to check in and see how you're doing. Let's catch up soon!"]
new_X = cv.transform(new_msg)
result = model.predict(new_X)

print("New Message Prediction:", result[0])
# Out:
# Accuracy: 0.9802690582959641
# Confusion Matrix:
# [[948  14]
#  [  8 145]]
# New Message Prediction: ham
